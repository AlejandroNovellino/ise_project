# %% [markdown]
# # Pruebas para verificar el cumplimiento del objetivo B junto a C

# %% [markdown]
# ## Configuración Inicial y Autenticación

# %%
from utils import configure_headers


# configure the headers
configure_headers()

ENDPOINTS_TO_TEST = [
    # search
    "https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album",
    # get album
    "https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy",
    # get artist
    "https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg",
    # get playlist
    "https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n",
    # get track
    "https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl",
    # TODO Puedes añadir más endpoints aquí
]
# Out:
# ✅ Token loaded.

# %% [markdown]
# # Objetivo BC - Prueba de latencia con Red de 10 Mbps

# %% [markdown]
# Hacemos las pruebas para cumplir con el objetivo B y C, usando la conexión de 10 Mbps y la conexión por VPN a Argentina. Vamos a probar todos los endpoints que declaramos que son los servicios a estudiar, y vamos a tomar todas las mediciones para luego poder responder a las métricas establecidas.

# %%
from utils import simulate_concurrent_users


simulate_concurrent_users(
    num_users=30,
    num_requests_per_user=30,
    endpoints_to_test=ENDPOINTS_TO_TEST
)
# Out:
# --- Simulation started with 30 concurrent users ---
# Each user will do 30 requests.
#
# ✴️ Usuario 1 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748096918.3730695
# ✴️ Usuario 2 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748096918.4495704
# ✴️ Usuario 3 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748096918.4727998
# ✴️ Usuario 4 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748096918.5240266
# ✴️ Usuario 5 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748096918.5912087
# ✴️ Usuario 6 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748096918.6917355
# ...

# %% [markdown]
# ## Procesa los resultados

# %%
from utils import process_concurrent_results

# process the results
df_global_results, df_individual_results, df_by_endpoint = process_concurrent_results()
# Out:
# --- Resumen General de la Simulación Concurrente ---
# Total de usuarios simulados: 30
# Peticiones totales realizadas: 900
# Peticiones exitosas totales: 197
# Errores 4xx totales: 703
# Errores 5xx totales: 0
# Tasa de éxito global: 21.89%
# Tasa de error 4xx global: 78.11%
# Tasa de error 5xx global: 0.00%
# Latencia promedio: 0.411

# %%
print('\nGlobal results\n')
df_global_results
# Out:
# Global results
#     user_id                                           endpoint  \
# 0        12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 1        23  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 2        15  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 3         4  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 4        14  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 5         7  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 6        22  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 7        17  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 8        10  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 9        30  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 10        2  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 11       20  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 12       19  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 13        3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# ...

# %%
print('\nIndividual results\n')
df_individual_results
# Out:
# Individual results
#      user_ids                                          endpoints  \
# 0          12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 1          12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 2          12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 3          12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 4          12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# ..        ...                                                ...
# 895         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 896         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 897         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 898         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 899         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
#
#      status_codes  latencies         times  error_intervals
# 0             429   0.253939  1.748097e+09              NaN
# ...

# %%
print('\nResults by endpoint\n')
df_by_endpoint
# Out:
# Results by endpoint
#                                             endpoint  total_requests  \
# 0  https://api.spotify.com/v1/albums/4aawyAB9vmqN...             180
# 1  https://api.spotify.com/v1/artists/0TnOYISbd1X...             180
# 2  https://api.spotify.com/v1/playlists/3cEYpjA9o...             180
# 3  https://api.spotify.com/v1/search?q=remaster%2...             180
# 4  https://api.spotify.com/v1/tracks/11dFghVXANMl...             180
#
#    successful_requests  error_4xx_requests  error_5xx_requests  avg_latency  \
# 0                    0                 180                   0     0.370239
# 1                    0                 180                   0     0.408817
# 2                   99                  81                   0     0.423928
# 3                   98                  82                   0     0.484913
# 4                    0                 180                   0     0.367210
#
#    num_users  success_rate  error_4xx_rate  error_5xx_rate
# ...

# %% [markdown]
# ## Guardamos los resultados base

# %%
df_global_results.to_csv('./files/obj-BC/global_results.csv', index=False)
df_individual_results.to_csv('./files/obj-BC/individual_results.csv', index=False)
df_by_endpoint.to_csv('./files/obj-BC/endpoints_results.csv', index=False)
