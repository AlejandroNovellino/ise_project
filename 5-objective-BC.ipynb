# %% [markdown]
# # Pruebas para verificar el cumplimiento del objetivo específico C

# %% [markdown]
# ## Configuración Inicial y Autenticación

# %%
import os
import requests
import threading
import pandas as pd
import random
from dotenv import load_dotenv

# %%
# function to get the access token
def get_access_token(client_id, client_secret):
    token_url = "https://accounts.spotify.com/api/token"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }
    try:
        response = requests.post(token_url, headers=headers, data=data)
        response.raise_for_status()

        print('✅ Token loaded.')

        return response.json()["access_token"]
    except requests.exceptions.RequestException as e:
        print(f"Error al obtener el token de acceso: {e}")
        return None

# %%
# configuration
load_dotenv()

CLIENT_ID = os.environ.get('CLIENT_ID')
CLIENT_SECRET = os.environ.get('CLIENT_SECRET')

# get the access token
ACCESS_TOKEN = get_access_token(CLIENT_ID, CLIENT_SECRET)
if not ACCESS_TOKEN:
    print("No se pudo obtener el token de acceso. Las pruebas no pueden continuar.")
    exit()

HEADERS = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

ENDPOINTS_TO_TEST = [
    # search
    "https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album",
    # get album
    "https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy",
    # get artist
    "https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg",
    # get playlist
    "https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n",
    # get track
    "https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl",
    # TODO Puedes añadir más endpoints aquí
]

# variables to save the results
results_lock = threading.Lock()
concurrent_test_results = []
concurrent_test_individual_results = {
    'user_ids': [],
    'endpoints': [],
    'status_codes': [],
    'latencies': [],
    'times': [] # Para registrar el tiempo en que se realizó la petición
}
# Out:
# ✅ Token loaded.

# %% [markdown]
# ## Funcion de concurrencia para realizar las pruebas

# %%
import time


def user_simulation_task(user_id, endpoint, headers, num_requests_per_user):
    """
    Simula el comportamiento de un único usuario haciendo peticiones a un endpoint.
    """

    user_results = {
        'user_id': user_id,
        'endpoint': endpoint,
        'total_requests': 0,
        'successful_requests': 0,
        'error_4xx_requests': 0,
        'error_5xx_requests': 0,
        'total_response_time': 0,
        'latencies': [], # Para registrar tiempos de respuesta individuales
        'errors_occurred': [], # Para registrar códigos de error
        'test_duration': 0
    }

    user_ids = []
    endpoints = []
    status_codes = []
    latencies = []
    times = []

    # test info
    test_start_time = time.time()
    print(f"✴️ Usuario {user_id} - Starting requests to {endpoint}. - Test started at {test_start_time}")

    # do requests for the given amount
    for i in range(num_requests_per_user):

        start_time = time.time()

        try:
            # request
            response = requests.get(endpoint, headers=headers)

            # ☑️ save the data to study

            #   save the whole test results
            duration = time.time() - start_time
            user_results['total_requests'] += 1
            user_results['total_response_time'] += duration
            user_results['latencies'].append(duration)
            status_code = response.status_code

            #   save the individual test results
            user_ids.append(user_id)
            endpoints.append(endpoint)
            status_codes.append(status_code)
            latencies.append(duration)
            times.append(time.time()) # save the time in floating point

            if 200 <= status_code < 300: # if request successful
                user_results['successful_requests'] += 1

            elif 400 <= status_code < 500: # if request of kind 4xx
                user_results['error_4xx_requests'] += 1
                user_results['errors_occurred'].append(status_code)

                if status_code == 429: # if request of kind 429 (to many requests)
                    print(f"Usuario {user_id} - Alerta: Recibido 429 (Too Many Requests).")

                    #retry_after = response.headers.get('Retry-After')
                    # if retry_after:
                    #     wait_time = int(retry_after) + 1
                    #     print(f"Usuario {user_id} - Esperando {wait_time}s antes de reintentar.")
                    #     time.sleep(wait_time) # Esperar antes de la próxima petición

            elif 500 <= status_code < 600:
                user_results['error_5xx_requests'] += 1
                user_results['errors_occurred'].append(status_code)
                print(f"Usuario {user_id} - Error 5xx ({status_code}) en {endpoint}.")

        except requests.exceptions.RequestException as e:

            user_results['total_requests'] += 1 # Contar también las peticiones con excepción
            user_results['errors_occurred'].append(str(e)) # Registrar la excepción
            print(f"Usuario {user_id} - Excepción de red para {endpoint}: {e}")

        finally:
            time.sleep(1) # wait 1 second before the next request

    test_finish_time = time.time()
    test_duration = test_finish_time - test_start_time

    # save the test duration
    user_results['test_duration'] = test_duration

    print(f"✅ User {user_id} - Finished requests to {endpoint}. - Test finished at {test_finish_time}. Duration: {test_duration:.2f}s")

    # add the results to the global results
    with results_lock:
        # save the whole test results
        concurrent_test_results.append(user_results)
        # save the individual test results
        concurrent_test_individual_results['user_ids'].extend(user_ids)
        concurrent_test_individual_results['endpoints'].extend(endpoints)
        concurrent_test_individual_results['status_codes'].extend(status_codes)
        concurrent_test_individual_results['latencies'].extend(latencies)
        concurrent_test_individual_results['times'].extend(times)

# %% [markdown]
# ## Orquestacion de usuarios concurrentes

# %% [markdown]
# Simulamos multiples usuarios de forma concurrente para probar los endpoints de la API de Spotify.

# %%
def simulate_concurrent_users(num_users, num_requests_per_user, endpoints_to_test):
    """
    Orquesta la simulación de múltiples usuarios concurrentes.

    Args:
        num_users (int): El número de usuarios a simular.
        num_requests_per_user (int): El número de peticiones que cada usuario hará.
        endpoints_to_test (list): Lista de endpoints a los que los usuarios harán peticiones.
                                  Los usuarios se distribuirán entre estos endpoints.
    """

    print(f"\n--- Simulation started with {num_users} concurrent users ---")
    print(f"Each user will do {num_requests_per_user} requests.\n")

    threads = []

    # create a thread for each user
    endpoint_index = 0

    for i in range(num_users):
        # select the endpoint for the user
        selected_endpoint = endpoints_to_test[endpoint_index % len(endpoints_to_test)]

        # create the thread
        thread = threading.Thread(
            target=user_simulation_task,
            args=(i + 1, selected_endpoint, HEADERS, num_requests_per_user)
        )
        threads.append(thread)
        thread.start() # Inicia el hilo
        endpoint_index += 1

        # wait i little for the next thread
        time.sleep(random.uniform(0.01, 0.1))

    # wait to each thread to finish
    for thread in threads:
        thread.join()

    print("\n--- Simulation finished ---")

# %% [markdown]
# # Objetivo C

# %% [markdown]
# Hacemos las pruebas base para cumplir con el objetivo A. Vamos a probar todos los endpoints que declaramos que son los servicios a estudiar, y vamos a tomar todas las mediciones para luego poder responder a las metricas establecidas.

# %%
simulate_concurrent_users(
    num_users=30,
    num_requests_per_user=30,
    endpoints_to_test=ENDPOINTS_TO_TEST
)
# Out:
# --- Simulation started with 30 concurrent users ---
# Each user will do 30 requests.
#
# ✴️ Usuario 1 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033154.1790674
# ✴️ Usuario 2 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033154.2554948
# ✴️ Usuario 3 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033154.3369434
# ✴️ Usuario 4 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033154.4129033
# ✴️ Usuario 5 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033154.432961
# ✴️ Usuario 6 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033154.4861376
# ✴️ Usuario 7 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033154.5449946
# ✴️ Usuario 8 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033154.5700054
# ✴️ Usuario 9 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033154.6075904
# ✴️ Usuario 10 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033154.62579
# ✴️ Usuario 11 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033154.6967297
# ✴️ Usuario 12 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033154.7968726
# ✴️ Usuario 13 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033154.8551576
# ✴️ Usuario 14 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033154.8868883
# ✴️ Usuario 15 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033154.9506862
# ✴️ Usuario 16 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033154.9770877
# ✴️ Usuario 17 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033155.0045462
# ✴️ Usuario 18 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033155.0804815
# ✴️ Usuario 19 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033155.148498
# ✴️ Usuario 20 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033155.2350714
# ✴️ Usuario 21 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033155.262873
# ✴️ Usuario 22 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033155.3409255
# ✴️ Usuario 23 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033155.3940463
# ✴️ Usuario 24 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033155.490208
# ✴️ Usuario 25 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033155.5522275
# ✴️ Usuario 26 - Starting requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test started at 1748033155.6395388
# ✴️ Usuario 27 - Starting requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test started at 1748033155.70802
# ✴️ Usuario 28 - Starting requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test started at 1748033155.7841327
# ✴️ Usuario 29 - Starting requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test started at 1748033155.8604147
# ✴️ Usuario 30 - Starting requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test started at 1748033155.9492633
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 8 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 13 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 7 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 18 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 12 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 3 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 3 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033194.5310597. Duration: 40.19s
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 8 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033194.7767527. Duration: 40.21s
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 17 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 13 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033195.0367134. Duration: 40.18s
# Usuario 15 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 22 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 18 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033195.2764978. Duration: 40.20s
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 4 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 20 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 19 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 7 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033195.384387. Duration: 40.84s
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 23 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 12 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033195.6876495. Duration: 40.89s
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 17 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033195.8202367. Duration: 40.82sUsuario 21 - Alerta: Recibido 429 (Too Many Requests).
#
# Usuario 14 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 6 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 30 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 15 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033196.089123. Duration: 41.14s
# ✅ User 22 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033196.0906532. Duration: 40.75s
# Usuario 1 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 4 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033196.3620665. Duration: 41.95s
# ✅ User 20 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033196.3710892. Duration: 41.14s
# ✅ User 19 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033196.3783455. Duration: 41.23s
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 23 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033196.5125837. Duration: 41.12s
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 25 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 5 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 14 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033196.9497304. Duration: 42.06s
# ✅ User 6 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033196.981281. Duration: 42.50s
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 30 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033197.0511653. Duration: 41.10s
# ✅ User 1 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033197.0947971. Duration: 42.92s
# Usuario 21 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 24 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 9 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 25 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033197.5776827. Duration: 42.03s
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 5 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033197.671268. Duration: 43.24s
# Usuario 29 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 10 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 16 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 2 - Alerta: Recibido 429 (Too Many Requests).
# Usuario 28 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 21 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033198.119484. Duration: 42.86s
# Usuario 26 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 24 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033198.3112862. Duration: 42.82s
# ✅ User 9 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033198.3209887. Duration: 43.71s
# ✅ User 29 - Finished requests to https://api.spotify.com/v1/playlists/3cEYpjA9oz9GiPac4AsH4n. - Test finished at 1748033198.7350433. Duration: 42.87s
# ✅ User 10 - Finished requests to https://api.spotify.com/v1/tracks/11dFghVXANMlKmJXsNCbNl. - Test finished at 1748033198.860826. Duration: 44.24s
# Usuario 27 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 16 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033198.9134297. Duration: 43.94s
# Usuario 11 - Alerta: Recibido 429 (Too Many Requests).
# ✅ User 2 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033198.995144. Duration: 44.74s
# ✅ User 28 - Finished requests to https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg. - Test finished at 1748033199.0074384. Duration: 43.22s
# ✅ User 11 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033201.4070666. Duration: 46.71s
# ✅ User 26 - Finished requests to https://api.spotify.com/v1/search?q=remaster%2520track%3ADoxy%2520artist%3AMiles%2520Davis&type=album. - Test finished at 1748033202.3713682. Duration: 46.73s
# ✅ User 27 - Finished requests to https://api.spotify.com/v1/albums/4aawyAB9vmqN3uQ7FjRGTy. - Test finished at 1748033202.6568882. Duration: 46.95s
#
# --- Simulation finished ---

# %% [markdown]
# ## Procesa los resultados

# %%
def process_concurrent_results():
    """
    Consolida y analiza los resultados de la simulación de usuarios concurrentes.
    """
    if not concurrent_test_results:
        print("No hay resultados para procesar de la simulación concurrente.")
        return

    df_concurrent = pd.DataFrame(concurrent_test_results)
    df_concurrent_2 = pd.DataFrame(concurrent_test_individual_results)

    # global calculates
    global_total_requests = df_concurrent['total_requests'].sum()
    global_successful_requests = df_concurrent['successful_requests'].sum()
    global_error_4xx_requests = df_concurrent['error_4xx_requests'].sum()
    global_error_5xx_requests = df_concurrent['error_5xx_requests'].sum()
    global_success_rate = (global_successful_requests / global_total_requests) * 100 if global_total_requests > 0 else 0
    global_error_4xx_rate = (global_error_4xx_requests / global_total_requests) * 100 if global_total_requests > 0 else 0
    global_error_5xx_rate = (global_error_5xx_requests / global_total_requests) * 100 if global_total_requests > 0 else 0

    # global results
    print("\n--- Resumen General de la Simulación Concurrente ---")
    print(f"Total de usuarios simulados: {len(df_concurrent)}")
    print(f"Peticiones totales realizadas: {df_concurrent['total_requests'].sum()}")
    print(f"Peticiones exitosas totales: {df_concurrent['successful_requests'].sum()}")
    print(f"Errores 4xx totales: {df_concurrent['error_4xx_requests'].sum()}")
    print(f"Errores 5xx totales: {df_concurrent['error_5xx_requests'].sum()}")
    print(f"Tasa de éxito global: {global_success_rate:.2f}%")
    print(f"Tasa de error 4xx global: {global_error_4xx_rate:.2f}%")
    print(f"Tasa de error 5xx global: {global_error_5xx_rate:.2f}%")

    # analysis by endpoint
    agg_by_endpoint = df_concurrent.groupby('endpoint').agg(
        total_requests=('total_requests', 'sum'),
        successful_requests=('successful_requests', 'sum'),
        error_4xx_requests=('error_4xx_requests', 'sum'),
        error_5xx_requests=('error_5xx_requests', 'sum'),
        avg_latency=('latencies', lambda x: pd.Series([item for sublist in x for item in sublist]).mean()),
        num_users=('user_id', 'nunique')
    ).reset_index()

    agg_by_endpoint['success_rate'] = (agg_by_endpoint['successful_requests'] / agg_by_endpoint['total_requests']) * 100
    agg_by_endpoint['error_4xx_rate'] = (agg_by_endpoint['error_4xx_requests'] / agg_by_endpoint['total_requests']) * 100
    agg_by_endpoint['error_5xx_rate'] = (agg_by_endpoint['error_5xx_requests'] / agg_by_endpoint['total_requests']) * 100

    return df_concurrent, df_concurrent_2, agg_by_endpoint

# %%
# process the results
df_global_results, df_individual_results, df_by_endpoint = process_concurrent_results()
# Out:
# --- Resumen General de la Simulación Concurrente ---
# Total de usuarios simulados: 30
# Peticiones totales realizadas: 900
# Peticiones exitosas totales: 505
# Errores 4xx totales: 395
# Errores 5xx totales: 0
# Tasa de éxito global: 56.11%
# Tasa de error 4xx global: 43.89%
# Tasa de error 5xx global: 0.00%

# %%
print('\nGlobal results\n')
df_global_results
# Out:
# Global results
#     user_id                                           endpoint  \
# 0         3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 1         8  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 2        13  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 3        18  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 4         7  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 5        12  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 6        17  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 7        15  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 8        22  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 9         4  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 10       20  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 11       19  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 12       23  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 13       14  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 14        6  https://api.spotify.com/v1/search?q=remaster%2...
# 15       30  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 16        1  https://api.spotify.com/v1/search?q=remaster%2...
# 17       25  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 18        5  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 19       21  https://api.spotify.com/v1/search?q=remaster%2...
# 20       24  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 21        9  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 22       29  https://api.spotify.com/v1/playlists/3cEYpjA9o...
# 23       10  https://api.spotify.com/v1/tracks/11dFghVXANMl...
# 24       16  https://api.spotify.com/v1/search?q=remaster%2...
# 25        2  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 26       28  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 27       11  https://api.spotify.com/v1/search?q=remaster%2...
# 28       26  https://api.spotify.com/v1/search?q=remaster%2...
# 29       27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
#
#     total_requests  successful_requests  error_4xx_requests  \
# 0               30                   18                  12
# 1               30                   19                  11
# 2               30                   16                  14
# 3               30                   16                  14
# 4               30                   17                  13
# 5               30                   17                  13
# 6               30                   17                  13
# 7               30                   17                  13
# 8               30                   18                  12
# 9               30                   17                  13
# 10              30                   17                  13
# 11              30                   18                  12
# 12              30                   17                  13
# 13              30                   17                  13
# 14              30                   15                  15
# 15              30                   16                  14
# 16              30                   16                  14
# 17              30                   17                  13
# 18              30                   17                  13
# 19              30                   17                  13
# 20              30                   17                  13
# 21              30                   17                  13
# 22              30                   14                  16
# 23              30                   17                  13
# 24              30                   16                  14
# 25              30                   19                  11
# 26              30                   17                  13
# 27              30                   16                  14
# 28              30                   17                  13
# 29              30                   16                  14
#
#     error_5xx_requests  total_response_time  \
# 0                    0            10.166088
# 1                    0            10.182197
# 2                    0            10.157712
# 3                    0            10.170161
# 4                    0            10.813255
# 5                    0            10.865936
# 6                    0            10.785423
# 7                    0            11.107666
# 8                    0            10.725132
# 9                    0            11.922026
# 10                   0            11.107748
# 11                   0            11.205185
# 12                   0            11.093122
# 13                   0            12.038089
# 14                   0            12.470665
# 15                   0            11.075644
# 16                   0            12.894640
# 17                   0            12.001368
# 18                   0            13.209953
# 19                   0            12.830619
# 20                   0            12.767696
# 21                   0            13.688913
# 22                   0            12.851589
# 23                   0            14.206877
# 24                   0            13.908049
# 25                   0            14.701045
# 26                   0            13.196084
# 27                   0            16.680418
# 28                   0            16.703740
# 29                   0            16.922722
#
#                                             latencies  \
# 0   [0.3377106189727783, 0.3487071990966797, 0.339...
# 1   [0.40303945541381836, 0.36658549308776855, 0.3...
# 2   [0.3639378547668457, 0.35804176330566406, 0.38...
# 3   [0.38202881813049316, 0.3550088405609131, 0.37...
# 4   [0.38052892684936523, 0.45794200897216797, 0.3...
# 5   [0.4202277660369873, 0.37602996826171875, 0.39...
# 6   [0.38821911811828613, 0.4223060607910156, 0.39...
# 7   [0.3185877799987793, 0.36008381843566895, 0.34...
# 8   [0.3790762424468994, 0.39263248443603516, 0.36...
# 9   [0.39400577545166016, 0.47379255294799805, 0.3...
# 10  [0.33226704597473145, 0.3538374900817871, 0.38...
# 11  [0.36858129501342773, 0.4452857971191406, 0.45...
# 12  [0.3664999008178711, 0.36486220359802246, 0.33...
# 13  [0.4169027805328369, 0.40061163902282715, 0.40...
# 14  [0.5443747043609619, 0.46685242652893066, 0.49...
# 15  [0.3372042179107666, 0.337266206741333, 0.3520...
# 16  [0.5903396606445312, 0.5408947467803955, 0.459...
# 17  [0.3258967399597168, 0.36040377616882324, 0.32...
# 18  [0.3359391689300537, 0.3807957172393799, 0.389...
# 19  [0.5071902275085449, 0.4979679584503174, 0.477...
# 20  [0.37801527976989746, 0.4391930103302002, 0.37...
# 21  [0.3665025234222412, 0.3786165714263916, 0.370...
# 22  [0.37287282943725586, 0.4497060775756836, 0.38...
# 23  [0.33496642112731934, 0.3561129570007324, 0.32...
# 24  [0.5454881191253662, 0.5825433731079102, 0.482...
# 25  [0.3983473777770996, 0.3983321189880371, 0.387...
# 26  [0.36823248863220215, 0.3784184455871582, 0.37...
# 27  [0.5014820098876953, 0.5735218524932861, 0.501...
# 28  [0.49541211128234863, 0.5072886943817139, 0.47...
# 29  [0.4403653144836426, 0.4065239429473877, 0.381...
#
#                                       errors_occurred  test_duration
# 0   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.194116
# 1   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.206747
# 2   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.181556
# 3   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.196016
# 4   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.839392
# 5   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.890777
# 6   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.815691
# 7   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.138437
# 8   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      40.749728
# 9   [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.949163
# 10  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.136018
# 11  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.229847
# 12  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.118537
# 13  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.062842
# 14  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.495143
# 15  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      41.101902
# 16  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.915730
# 17  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.025455
# 18  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      43.238307
# 19  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.856611
# 20  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.821078
# 21  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      43.713398
# 22  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      42.874629
# 23  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      44.235036
# 24  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      43.936342
# 25  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      44.739649
# 26  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      43.223306
# 27  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      46.710337
# 28  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      46.731829
# 29  [429, 429, 429, 429, 429, 429, 429, 429, 429, ...      46.948868

# %%
print('\nIndividual results\n')
df_individual_results
# Out:
# Individual results
#      user_ids                                          endpoints  \
# 0           3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 1           3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 2           3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 3           3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# 4           3  https://api.spotify.com/v1/artists/0TnOYISbd1X...
# ..        ...                                                ...
# 895        27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 896        27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 897        27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 898        27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
# 899        27  https://api.spotify.com/v1/albums/4aawyAB9vmqN...
#
#      status_codes  latencies         times
# 0             200   0.337711  1.748033e+09
# 1             200   0.348707  1.748033e+09
# 2             200   0.339735  1.748033e+09
# 3             200   0.369510  1.748033e+09
# 4             200   0.341233  1.748033e+09
# ..            ...        ...           ...
# 895           429   0.317581  1.748033e+09
# 896           429   0.317628  1.748033e+09
# 897           429   0.312553  1.748033e+09
# 898           200   0.381497  1.748033e+09
# 899           200   0.384380  1.748033e+09
#
# [900 rows x 5 columns]

# %%
print('\nResults by endpoint\n')
df_by_endpoint
# Out:
# Results by endpoint
#                                             endpoint  total_requests  \
# 0  https://api.spotify.com/v1/albums/4aawyAB9vmqN...             180
# 1  https://api.spotify.com/v1/artists/0TnOYISbd1X...             180
# 2  https://api.spotify.com/v1/playlists/3cEYpjA9o...             180
# 3  https://api.spotify.com/v1/search?q=remaster%2...             180
# 4  https://api.spotify.com/v1/tracks/11dFghVXANMl...             180
#
#    successful_requests  error_4xx_requests  error_5xx_requests  avg_latency  \
# 0                  104                  76                   0     0.415631
# 1                  103                  77                   0     0.360919
# 2                  100                  80                   0     0.413742
# 3                   97                  83                   0     0.474934
# 4                  101                  79                   0     0.403940
#
#    num_users  success_rate  error_4xx_rate  error_5xx_rate
# 0          6     57.777778       42.222222             0.0
# 1          6     57.222222       42.777778             0.0
# 2          6     55.555556       44.444444             0.0
# 3          6     53.888889       46.111111             0.0
# 4          6     56.111111       43.888889             0.0

# %% [markdown]
# ## Guardamos los resultados base

# %%
df_global_results.to_csv('./files/obj-C/global_results.csv', index=False)
df_individual_results.to_csv('./files/obj-C/individual_results.csv', index=False)
df_by_endpoint.to_csv('./files/obj-C/endpoints_results.csv', index=False)
